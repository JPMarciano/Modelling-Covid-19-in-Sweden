# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(f'owid-covid-data.csv')

# %%
df.loc[df["iso_code"]=="SWE"]
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 35223      SWE    Europe   Sweden  2019-12-31          0.0        0.0
# 35224      SWE    Europe   Sweden  2020-01-01          0.0        0.0
# 35225      SWE    Europe   Sweden  2020-01-02          0.0        0.0
# 35226      SWE    Europe   Sweden  2020-01-03          0.0        0.0
# 35227      SWE    Europe   Sweden  2020-01-04          0.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 35467      SWE    Europe   Sweden  2020-08-31      84232.0       48.0
# 35468      SWE    Europe   Sweden  2020-09-01      84394.0      162.0
# 35469      SWE    Europe   Sweden  2020-09-02      84566.0      172.0
# 35470      SWE    Europe   Sweden  2020-09-03      84729.0      163.0
# 35471      SWE    Europe   Sweden  2020-09-04      84729.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
cleandf = df[df["iso_code"]=="SWE"]
cleandf = cleandf[['date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'new_cases_smoothed', 'new_deaths_smoothed']]
cleandf
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths  \
# 35223  2019-12-31          0.0        0.0           0.0         0.0
# 35224  2020-01-01          0.0        0.0           0.0         0.0
# 35225  2020-01-02          0.0        0.0           0.0         0.0
# 35226  2020-01-03          0.0        0.0           0.0         0.0
# 35227  2020-01-04          0.0        0.0           0.0         0.0
# ...           ...          ...        ...           ...         ...
# 35467  2020-08-31      84232.0       48.0        5831.0         2.0
# 35468  2020-09-01      84394.0      162.0        5831.0         0.0
# 35469  2020-09-02      84566.0      172.0        5832.0         1.0
# 35470  2020-09-03      84729.0      163.0        5832.0         0.0
# 35471  2020-09-04      84729.0        0.0        5832.0         0.0
#
#        new_cases_smoothed  new_deaths_smoothed
# 35223                 NaN                  NaN
# 35224                 NaN                  NaN
# ...

# %%
cleandf.set_index('date')[['new_cases','new_deaths']].plot()

# %%
cleandf.set_index('date')[['new_cases','new_deaths','new_cases_smoothed', 'new_deaths_smoothed']].plot()

# %%
cleandf.set_index('date')[['total_cases','total_deaths']].plot()

# %%
cleandf.set_index('date')[['total_deaths']].plot()
